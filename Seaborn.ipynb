# %%
"""seaborn is another library for data visualisation , it is statistical ploting library which is 
build on the top of matplotlib , all the capability that you see in matplotlib , that will also in 
seaborn + seaborn is also used for advanced Data visualisation techniques , it works very well with 
pandas datatype objects  
"""
# Out:
# 'seaborn is another library for data visualisation , it is statistical ploting library which is \nbuild on the top of matplotlib , all the capability that you see in matplotlib , that will also in \nseaborn + seaborn is also used for advanced Data visualisation techniques , it works very well with \npandas datatype objects  \n'

# %%
import seaborn as sns
import numpy as np
import pandas as pd

# %%
# link : https://seaborn.pydata.org/

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# Data visualisation using seaborn on data set named tips

# %%
sns.barplot(x="sex",y="total_bill",data=tips,estimator=np.std)

# %%
#count plot
sns.countplot(x='sex',data=tips)

# %%
sns.countplot(x='time',data=tips)

# %%
#box plot
sns.boxplot(x="day",y="total_bill",data=tips,hue="smoker")

# it trepresent categorial data , here box represnt most of data and line between same colured boxes represnt mean
# above point outliers (excepional data (not take these line seriously ))

# %%
 #box plot
sns.boxplot(x="day",y="total_bill",data=tips,hue="sex")

# %%
#we obseve on every day males are spending more money and on sonday most feamales come

# %%
sns.violinplot(x='day',y='total_bill',data=tips,hue='sex')

# %%
 #on both side they are covering same area so using split you can merge (unwanted description soory , please see documentation )
 sns.violinplot(x='day',y='total_bill',data=tips,hue='sex', split=True)

# %% [markdown]
# ###Distribution plot

# %%
# Distribution plot allows you to show distribution of one variable

# %%
#the curvy line that you see here is KDE (kernel density estimation) , you can remove by making it false 
#bins is not just it is long blocks default it is 10


sns.distplot(tips['total_bill'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(tips['total_bill'],kde=False,bins=30,)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.kdeplot(tips['total_bill'])

# %%
# Join Plot : distribution between two plot , meaning you can combine two distribution plot in one graph

# %%
#default kind of join plot is scatter 
sns.jointplot(x="total_bill",y="tip",data=tips)

# %%
sns.jointplot(x="total_bill",y="tip",data=tips,kind='hex',color="red")

# %%
sns.jointplot(x="total_bill",y="tip",data=tips,kind='kde',)

# %%
sns.jointplot(x="total_bill",y="tip",data=tips,kind='reg',)

# %%
# ? what if you want to caompare all the features and thier relation between all the features , for this we use pair plot

# %%
#pair plot : it represent pair wise relation between all the features

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips,hue='sex')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips_corr = tips.corr()

# %%
print(tips_corr)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
 tips_corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
#if one thing is increasing and other thing is decreasing then it is negative correlation

# %%
# to get value on graph you can use annot


sns.heatmap(tips_corr , annot=True)

# %%
# in heat map you have variable on both row and column (some pandas dataframe)

# %%
# one another  method in pandas to create data frame which has variable on both row and column

# %%
flight = sns.load_dataset('flights')

# %%
flight
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flights_pivot =flight.pivot_table(index= 'month', columns='year' , values = 'passengers')

# %%
flights_pivot
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
#there are many color map which you can use by using cmap="coolwarm",

sns.heatmap(flights_pivot)

# %% [markdown]
# #Task
#
# ---
#
#
#
# ###Do data visualisation on TITANIC data set , find some awesome visualisation , come to some conslusion
